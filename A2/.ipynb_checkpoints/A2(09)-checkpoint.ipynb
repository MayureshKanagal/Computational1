# %% [markdown]
# Question 9

# %% [markdown]
# Solution (9a)

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt

def fun(x, y):
    return np.vstack((y[1], -np.exp(-2*y[0])))


def bc(ya, yb):                # Function evaluating residuals of the boundary conditions.
    return np.array([ya[0] - 0, yb[0] - np.log(2)])

start=1
stop= 2
n=10

x = np.linspace(start, stop,n)

y_guess = np.zeros((2, x.size))
y_guess[0, :] = np.exp(x)  
y_guess[1, :] = np.exp(x)  

sol = solve_bvp(fun, bc, x, y_guess)

print(sol)

x_plot = np.linspace(start, stop,10)
y_sol = sol.sol(x_plot)[0]
plt.plot(x_plot, y_sol, label='y(x)')
plt.title("Solution of the BVP")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [ 1.000e+00  1.111e+00  1.222e+00  1.333e+00  1.444e+00
#                   1.556e+00  1.667e+00  1.778e+00  1.889e+00  2.000e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x000001CAFAA3ABD0>
#              p: None
#              y: [[-5.061e-22  1.054e-01 ...  6.360e-01  6.931e-01]
#                  [ 1.000e+00  9.000e-01 ...  5.294e-01  5.000e-01]]
#             yp: [[ 1.000e+00  9.000e-01 ...  5.294e-01  5.000e-01]
#                  [-1.000e+00 -8.100e-01 ... -2.803e-01 -2.500e-01]]
#  rms_residuals: [ 7.900e-05  5.261e-05  3.622e-05  2.567e-05  1.862e-05
#                   1.373e-05  1.022e-05  7.677e-06  5.839e-06]
#          niter: 1

# %% [markdown]
# Solution (9b)

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt

def fun(x,y):
    return np.vstack((y[1], y[1] * np.cos(x) - y[0] * np.log(y[0])))


def bc(ya, yb):                # Function evaluating residuals of the boundary conditions.
    return np.array([ya[0] - 1, yb[0] - np.exp(1)])

start=0
stop= np.pi/2
n=10

x = np.linspace(start, stop,n)

y_guess = np.zeros((2, x.size))
y_guess[0, :] = np.exp(x)  
y_guess[1, :] = np.exp(x)  

sol = solve_bvp(fun, bc, x, y_guess)

print(sol)

x_plot = np.linspace(start, stop,10)
y_sol = sol.sol(x_plot)[0]
plt.plot(x_plot, y_sol, label='y(x)')
plt.title("Solution of the BVP")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [ 0.000e+00  1.745e-01  3.491e-01  5.236e-01  6.981e-01
#                   8.727e-01  1.047e+00  1.222e+00  1.396e+00  1.571e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x000001CAFAA30EF0>
#              p: None
#              y: [[ 1.000e+00  1.190e+00 ...  2.677e+00  2.718e+00]
#                  [ 1.000e+00  1.172e+00 ...  4.649e-01 -2.378e-06]]
#             yp: [[ 1.000e+00  1.172e+00 ...  4.649e-01 -2.378e-06]
#                  [ 1.000e+00  9.472e-01 ... -2.556e+00 -2.718e+00]]
#  rms_residuals: [ 1.345e-04  1.217e-04  7.715e-05  1.900e-04  3.433e-04
#                   3.329e-04  2.778e-04  2.303e-04  2.728e-04]
#          niter: 1

# %% [markdown]
# Solution (9c)

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt

def fun(x, y):
    return np.vstack((y[1], -((2 * (y[1])**3) + (y[0]**2 * y[1])) * (1 / np.cos(x))))


def bc(ya, yb):                # Function evaluating residuals of the boundary conditions.
    return np.array([ya[0] - 2**(-1/4), yb[0] - (12**(1/4))/2])

start=np.pi/4
stop= np.pi/3
n=10

x = np.linspace(start, stop,n)

y_guess = np.zeros((2, x.size))
y_guess[0, :] = np.exp(x)  
y_guess[1, :] = np.exp(x)  

sol = solve_bvp(fun, bc, x, y_guess)

print(sol)

x_plot = np.linspace(start, stop,10)
y_sol = sol.sol(x_plot)[0]
plt.plot(x_plot, y_sol, label='y(x)')
plt.title("Solution of the BVP")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [ 7.854e-01  7.886e-01 ...  1.044e+00  1.047e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x000001CAFAA3AEF0>
#              p: None
#              y: [[ 8.409e-01  8.423e-01 ...  9.297e-01  9.306e-01]
#                  [ 4.204e-01  4.184e-01 ...  2.704e-01  2.686e-01]]
#             yp: [[ 4.204e-01  4.184e-01 ...  2.704e-01  2.686e-01]
#                  [-6.307e-01 -6.290e-01 ... -5.435e-01 -5.429e-01]]
#  rms_residuals: [ 5.941e-08  5.910e-07 ...  2.598e-08  9.303e-08]
#          niter: 3

# %% [markdown]
# Solution (9d)

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt

def fun(x,y):
    return np.vstack((y[1], (1 - (y[1])**2 -y[0]* np.sin(x))/2 ))

def bc(ya, yb):               
    return np.array([ya[0] - 2, yb[0] - 2])

start=0
stop= np.pi
n=50

x = np.linspace(start, stop,n)

y_guess = np.zeros((2, x.size))
y_guess[0, :] = np.exp(x)  
y_guess[1, :] = np.exp(x)  

sol = solve_bvp(fun, bc, x, y_guess)

print(sol)

x_plot = np.linspace(start, stop,10)
y_sol = sol.sol(x_plot)[0]
plt.plot(x_plot, y_sol, label='y(x)')
plt.title("Solution of the BVP")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [ 0.000e+00  7.124e-03 ...  3.134e+00  3.142e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x00000168FB2CF7C0>
#              p: None
#              y: [[ 2.000e+00  2.007e+00 ...  2.007e+00  2.000e+00]
#                  [ 1.000e+00  1.000e+00 ... -1.000e+00 -1.000e+00]]
#             yp: [[ 1.000e+00  1.000e+00 ... -1.000e+00 -1.000e+00]
#                  [ 2.640e-06 -7.121e-03 ... -7.121e-03  2.651e-06]]
#  rms_residuals: [ 4.489e-06  4.326e-06 ...  4.479e-06  4.653e-06]
#          niter: 3
